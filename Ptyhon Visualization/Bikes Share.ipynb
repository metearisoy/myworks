# %% [markdown]
# ![yaz%C4%B1.png](attachment:yaz%C4%B1.png)

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings;
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv("store_sharing.csv")
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Veri Null değer içermiyor, Data temizliğine gerek duyulmadı.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
fig, ax = plt.subplots(2,2, figsize = (15,9))
sns.barplot(x = df.season, y = df.cnt, ax = ax[0][0])
sns.barplot(x = df.is_holiday, y = df.cnt, ax = ax[0][1])
sns.barplot(x = df.is_weekend, y = df.cnt, ax = ax[1][0])
sns.barplot(x = df.weather_code, y = df.cnt, ax = ax[1][1]);
plt.tight_layout()

# %% [markdown]
# Bisiklet kiralama sayısı en çok yaz ayında gözlemlenmiş olup en düşük kış ayındadır.Tatil günlerinde ve haftasonlarında diğer günlere nazaran kiralama sayısı düşüktür.

# %% [markdown]
# En yüksek kiralama sayısı sırasıyla az bulutlu,parçalı bulutlu ve güneşli günlerde gözlemlenmiştir. En düşük sayı kar yağışlı günlerde olup, buzlu sis gözlemlenmemiştir.

# %%
7146847 / 6150 #kontrol.
# Out:
# 1162.0889430894308

# %% [markdown]
# 7146847 / 6150

# %%
df[df.weather_code == 1]["cnt"].count() #kontrol.
# Out:
# 6150

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %%
plt.figure(figsize=(15, 9))
sns.countplot(x='weather_code',data=df);

# %% [markdown]
# Güneşli gün sayısı baskın olarak fazla olmasına rağmen bisiklet kiralanma sayısı, az bulutlu ve parçalı bulutlu günlerde daha fazla gözlemlenmiştir.

# %% [markdown]
# Fırtınalı gün sayısı çok az gözlemlenmişken bisiklet kiralanma sayısı azımsanmayacak kadar yüksektir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %%
df['year'] = df["timestamp"].dt.year

# %%
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season  year
# ...

# %%
df.dtypes
# Out:
# timestamp       datetime64[ns]
# cnt                      int64
# t1                     float64
# t2                     float64
# hum                    float64
# wind_speed             float64
# weather_code           float64
# is_holiday             float64
# is_weekend             float64
# season                 float64
# year                     int64
# dtype: object

# %%
df.set_index("timestamp", inplace = True)
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year
# timestamp
# ...

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
plt.figure(figsize=(15, 9))
sns.heatmap(df.corr(), center=0, cmap = 'Blues',annot= True);

# %% [markdown]
# Görüldüğü üzere en yüksek korelasyon gerçek sıcaklık ile hissedilen sıcaklık arasında, en düşüğü tatil günleri ve saatler arasında gözlemlenmiştir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year
# timestamp
# ...

# %%
df.corr()[["cnt"]].sort_values(by= "cnt", ascending=False)
# Out:
#                    cnt
# cnt           1.000000
# t1            0.388798
# t2            0.369035
# wind_speed    0.116295
# year          0.010046
# is_holiday   -0.051698
# is_weekend   -0.096499
# season       -0.116180
# weather_code -0.166633
# hum          -0.462901

# %%
df.corr()[["cnt"]].sort_values(by= "cnt").plot.barh(figsize = (15,7));

# %% [markdown]
# Bisiklet kiralama ile korelasyonu en düşük veri yıl olarak görülüp, en yüksek nem ile olduğu gözlemlenmiştir.Sıcaklık ile bisiklet kiralanma sayısı arasında korelasyon azımsanmayacak ölçüde yüksektir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
plt.figure(figsize = (16,8))
bike_shares_plot = sns.lineplot(x = df.year, y = df.cnt)
plt.xticks(rotation = 'vertical')
plt.title(label = "Bike Shares of Years");

# %%
plt.figure(figsize = (16,8))
sns.lineplot(x = df.index, y = "cnt", data = df);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
df["months"] = df.index.month

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months
# timestamp
# ...

# %%
fig, ax = plt.subplots(1,3, figsize = (14,7))
sns.lineplot(x = df.months, y = df.cnt, ax = ax[0])
sns.pointplot(x = df.months, y = df.cnt, ax = ax[1])
sns.barplot(x = df.months, y = df.cnt, ax = ax[2]);
plt.tight_layout()

# %% [markdown]
# Aralık,Ocak,Şubat ve Mart aylarında bisiklet kiralanma sayısı gözle görülür biçimde düşerken; Haziran,Temmuz Ağustos aylarında zirve yaptığı gözlemlenmiştir.

# %%
df["year_of_month"] = df.index.strftime("%Y-%m")

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
fig, ax = plt.subplots(3,1, figsize = (14,7))
plt.xticks(rotation = "vertical")
sns.lineplot(x = df.year_of_month, y = df.cnt, ax = ax[0])
sns.pointplot(x = df.year_of_month, y = df.cnt, ax = ax[1])
sns.barplot(x = df.year_of_month, y = df.cnt, ax = ax[2])
plt.tight_layout()

# %% [markdown]
# Ay grafiğinde görülen trendden farksız olarak yıllara göre bisiklet kiralanma sayısı, her yıl yaz aylarında artmış olup,kış aylarında belirgin bir şekilde düşmüştür.Bu trend her yıl kendini tekrarlamıştır.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
df["hours"] = df.index.hour

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
fig, ax = plt.subplots(3,1, figsize =(15,10))
sns.lineplot(data = df, x = "hours", y = "cnt", hue ="season", palette= "plasma",ax = ax[0]);
sns.lineplot(data = df, x = "hours", y = "cnt", hue = "is_weekend", ax = ax[1])
sns.lineplot(data = df, x = "hours", y = "cnt", hue = "is_holiday", ax = ax[2]);

# %% [markdown]
# Sabah 7 ile 9 arasında ve akşam 17-18 saatlerinde, mevsime bağlı olmaksızın bisiklet kiralanma sayısının zirve yaptığı görülmüştür. Bu durum iş günlerinde tekrar gözlemlenmiş olup,iş giriş ve çıkış saatlerine bağlı olduğu
# gözlemlenmiştir.

# %% [markdown]
# Haftasonları ve tatil günlerinde 13-15 saatleri arasında gözle görülür bir artış tespit edilmiştir.

# %%
fig, ax = plt.subplots(3,1, figsize =(27,15))
sns.barplot(data = df, x = "hours", y = "cnt", hue ="season", ax = ax[0]);
sns.barplot(data = df, x = "hours", y = "cnt", hue = "is_weekend", ax = ax[1])
sns.barplot(data = df, x = "hours", y = "cnt", hue = "is_holiday", ax = ax[2]);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
df["day_of_weeks"] = df.index.weekday

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
mapping = {0:"Monday", 1:'Tuesday', 2:"wednesday", 3:"thursday", 4:"Friday", 5:"Saturday", 6:"Sunday"}

# %%
df["day_of_weeks"] = df["day_of_weeks"].map(mapping)

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
plt.figure(figsize = (15,7))
sns.barplot(data = df, x = "day_of_weeks", y = "cnt", hue ="is_holiday");

# %%
plt.figure(figsize = (15,7))
sns.lineplot(data = df, x = "day_of_weeks", y = "cnt", hue ="is_holiday");

# %% [markdown]
# Haftaiçi kiralanma sayısı stabil olup, haftasonları düşüş gözlemlenmiştir. Tatil günlerinde en yüksek Pazartesi, en düşük Salı günlerinde gözlemlenmiştir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
df["day_of_months"] = df.index.strftime("%d")

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
plt.figure(figsize = (12,4))
sns.lineplot(data = df, x = "day_of_months", y = "cnt");

# %%
plt.figure(figsize = (12,4))
sns.barplot(data = df, x = "day_of_months", y = "cnt");

# %% [markdown]
# Ayın günlerine bakıldığında çok yüksek dalgalanmalar görülmemesiyle birlikte, en düşük kiralanma sayısı 31. günlerde görülmüş olup, en yüksek sayı 9. günlerde gözlemlenmiştir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
df[df.is_holiday == 1]
# Out:
#                      cnt   t1   t2   hum  wind_speed  weather_code  \
# timestamp
# 2015-04-03 00:00:00  279  8.0  6.0  82.0        10.0           7.0
# 2015-04-03 01:00:00  174  8.0  5.5  79.0        14.0           7.0
# 2015-04-03 02:00:00   89  7.5  5.5  84.5        12.0           7.0
# 2015-04-03 03:00:00   61  7.0  5.0  87.0        11.0           7.0
# 2015-04-03 04:00:00   46  7.0  6.0  93.0         6.0           7.0
# ...                  ...  ...  ...   ...         ...           ...
# 2017-01-02 19:00:00  433  3.0  0.0  81.0        11.0           1.0
# 2017-01-02 20:00:00  334  3.0  0.0  75.0        13.0           1.0
# 2017-01-02 21:00:00  233  2.5 -0.5  78.0        11.0           1.0
# 2017-01-02 22:00:00  201  2.0 -1.0  81.0        10.0           1.0
# 2017-01-02 23:00:00  145  1.0 -2.0  93.0        10.0           1.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# 2015-04-03 00:00:00         1.0         0.0     0.0  2015       4
# ...

# %%
#Seasonlar için tatil günlerinde yıl içerisinde ki satışlar. 
plt.figure(figsize = (15,7))
sns.barplot(data = df, x = df[df.is_holiday == 1].year, y = "cnt", hue = "season");

# %%
df[df.season == 2].cnt
# Out:
# timestamp
# 2015-09-01 00:00:00     235
# 2015-09-01 01:00:00     156
# 2015-09-01 02:00:00     127
# 2015-09-01 03:00:00      62
# 2015-09-01 04:00:00      79
#                        ...
# 2016-11-30 19:00:00    1560
# 2016-11-30 20:00:00     969
# 2016-11-30 21:00:00     657
# 2016-11-30 22:00:00     597
# 2016-11-30 23:00:00     322
# Name: cnt, Length: 4303, dtype: int64

# %%
df[(df.season == 2.0) & (df.is_holiday == 1)] #check.
# Out:
# Empty DataFrame
# Columns: [cnt, t1, t2, hum, wind_speed, weather_code, is_holiday, is_weekend, season, year, months, year_of_month, hours, day_of_weeks, day_of_months]
# Index: []

# %%
## Ayrı ayrı değerlendirmek istiyorsak.
fig, ax = plt.subplots(2,1, figsize =(15,10))
sns.lineplot(data = df, x = "year", y = "cnt", hue ="season", ax = ax[0]);
sns.lineplot(data = df, x = "year", y = "cnt", hue = "is_holiday", ax = ax[1]);

# %% [markdown]
# Tatil günlerinde en yüksek kiralanma sayısı 2016 yılının yaz ayında gözlemlenmiştir.En düşük 2015 yılının yaz ayında gözlemlenmiştir. 2017'ye dair yeterli veri bulunmamaktadır.

# %% [markdown]
#  Elimizdeki verilere göre Sonbaharda tatil olmadığı için gözlem yapılamamıştır.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
df
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season  year  months  \
# timestamp
# ...

# %%
#Burada ki piechart'da weekend değerinin weekday ile oranını gösteriyor.
fig, ax = plt.subplots(1,2, figsize = (20,12))
sns.barplot(x = df["is_weekend"] , y = df["cnt"] , ax = ax[0]);
plt.pie(x = df.groupby("is_weekend").cnt.mean(), labels = ["Weekday" , "Weekend"] , autopct= '%.2f' , textprops={'fontsize': 20}) ;

# %% [markdown]
# Ortalama olarak bakıldığında, kiralamaların %55.3 ü haftaiçinde, %44.7 si haftasonunda gerçekleşmiştir.

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
plt.figure(figsize = (15,7))
sns.countplot(data= df, x="weather_code", hue = "season");

# %%
plt.figure(figsize = (15,7))
sns.catplot(data= df, x="weather_code", y = "cnt",hue = "season", kind="bar");

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# Datamızda her ne kadar güneşli gün daha fazla olsa da bisiklet kiralanması bulutlu günlerde daha fazla gerçekleşmiştir.
# Mevsimsel olarak yaz aylarında yoğun olarak bisiklet kiralanmıştır,kışın oran düşmüştür ve bu trend her yıl tekrarlanmıştır.Fırtınalı günlerde de kiralanma oranı düşük olmayıp
# bunun sebebi gidilecek yere bir an önce varmak istenmesi olabilir.Bisiklet kiralanması ile en yüksek korelasyon negatif
# anlamda nem ile görülmüştür.Sıcaklık ile pozitif korelasyon bulunmaktadır.
# Saat olarak işe gidiş ve dönüş saatlerinde kiralama artmış olup, insanların işe gitmek için yoğun olarak bisiklet kiraladığı düşünülmektedir.
# İşe gidiş ve dönüş için bisiklet kiralanma iddiası haftaiçi daha yoğun bisiklet kiralanması ve tatil günlerinde daha az kiralanması ile desteklenmiştir.
# Ayın günlerinde yoğun bir dalgalanma görülmemekle birlikte, en düşük oranın 31. günlerde gözlemlenmesi her ayın 31 gün sürmemesi ile açıklanabilir.
# En yüksek oran ise 9. günlerde görülmüştür. Tatil günlerinde bisiklet kiralanma oranı 2016 da zirve yapmış olup en düşük 2015 yılının yaz ayındadır.
# 2017 ye dair yeterli veri bulunmamakla birlikte sonbaharda tatil olmadığı görülmüştür.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
